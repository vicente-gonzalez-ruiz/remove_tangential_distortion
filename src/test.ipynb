# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import remove_tangential_distortion
# Out:
# [__init__.py:21 <module>()] Running in Google Colab: False

# %%
image = cv2.normalize(cv2.imread("1678793849794.png", cv2.IMREAD_UNCHANGED), None, 0, 255, cv2.NORM_MINMAX)

# %%
#image = image[..., 0]

# %%
image.shape
# Out:
# (120, 160)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
warped_image = remove_tangential_distortion.image_trapezoidal_warping(image)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(warped_image)
plt.title('Corrected Image')
# Out:
# Text(0.5, 1.0, 'Corrected Image')

# %%
cv2.imwrite("warped_image.png", warped_image)
# Out:
# True
